# %% [markdown]
# Lab: 12 - Data Analysis with Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('./vgsales.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
most_common_publisher=df['Publisher'].mode()
most_common_publisher
# Out:
# 0    Electronic Arts
# dtype: object

# %%
df_most_Platform=df['Platform'].mode()
df_most_Platform
# Out:
# 0    DS
# dtype: object

# %%
df_most_Genre=df['Genre'].mode()
df_most_Genre
# Out:
# 0    Action
# dtype: object

# %%
top_twenty_highest_grossing_games = df[['Global_Sales','Name']].sort_values('Global_Sales', ascending=False).nlargest(20,'Global_Sales')
top_twenty_highest_grossing_games
# Out:
#     Global_Sales                                          Name
# 0          82.74                                    Wii Sports
# 1          40.24                             Super Mario Bros.
# 2          35.82                                Mario Kart Wii
# 3          33.00                             Wii Sports Resort
# 4          31.37                      Pokemon Red/Pokemon Blue
# 5          30.26                                        Tetris
# 6          30.01                         New Super Mario Bros.
# 7          29.02                                      Wii Play
# 8          28.62                     New Super Mario Bros. Wii
# 9          28.31                                     Duck Hunt
# 10         24.76                                    Nintendogs
# 11         23.42                                 Mario Kart DS
# 12         23.10                   Pokemon Gold/Pokemon Silver
# 13         22.72                                       Wii Fit
# ...

# %%
df_median_sales = df[df['NA_Sales'] == df['NA_Sales'].median()].sort_values('NA_Sales', ascending=False)
# median Value
na_median_sales=df_median_sales.iloc[0].NA_Sales
# median First Name Value
ten_median_na_seller_names = df_median_sales.iloc[0].Name
df_median_sales[['NA_Sales','Name']][0:10]
# Out:
#        NA_Sales                               Name
# 446        0.08                  Dragon Warrior IV
# 10545      0.08              Hunter: The Reckoning
# 10533      0.08       Dora & Kai-Lan's Pet Shelter
# 10532      0.08  Hot Wheels: Stunt Track Challenge
# 10526      0.08                        FIFA Street
# 10523      0.08               Colin McRae Rally 04
# 10516      0.08                Dora's Cooking Club
# 10509      0.08               Blitz: The League II
# 10508      0.08                 Beyond Good & Evil
# 10491      0.08                            Syberia

# %%
df_max = (df['NA_Sales'].max(),df['NA_Sales'].mean())/df['NA_Sales'].std()
df_max
# Out:
# array([50.80306375,  0.32407607])

# %%
df_wii=df[df['Platform']=='Wii']['Global_Sales'].mean()
df_wii,df['Global_Sales'].mean()
# Out:
# (0.6994037735849057, 0.5374406555006628)

# %%
##################################################################
######################### TEST ###################################
##################################################################
def test():

    def assert_equal(actual,expected):
        assert actual == expected, f"Expected {expected} but got {actual}"

    assert_equal(most_common_publisher.values, "Electronic Arts")
    assert_equal(df_most_Platform.values, "DS")
    assert_equal(df_most_Genre.values, "Action")
    assert_equal(top_twenty_highest_grossing_games.iloc[0].Name, "Wii Sports")
    assert_equal(top_twenty_highest_grossing_games.iloc[19].Name, "Brain Age: Train Your Brain in Minutes a Day")
    assert_equal(na_median_sales, 0.08)
    assert_equal(ten_median_na_seller_names, "Dragon Warrior IV")

    print("Success!!!")

test()
# Out:
# Success!!!

# %% [markdown]
# Q1 => Get the 10 top ranked Wii platform productions

# %%
df[df['Platform'] == 'Wii'].sort_values('Rank', ascending=True)[0:10]
# Out:
#     Rank                       Name Platform    Year     Genre Publisher  \
# 0      1                 Wii Sports      Wii  2006.0    Sports  Nintendo
# 2      3             Mario Kart Wii      Wii  2008.0    Racing  Nintendo
# 3      4          Wii Sports Resort      Wii  2009.0    Sports  Nintendo
# 7      8                   Wii Play      Wii  2006.0      Misc  Nintendo
# 8      9  New Super Mario Bros. Wii      Wii  2009.0  Platform  Nintendo
# 13    14                    Wii Fit      Wii  2007.0    Sports  Nintendo
# 14    15               Wii Fit Plus      Wii  2009.0    Sports  Nintendo
# 39    40    Super Smash Bros. Brawl      Wii  2008.0  Fighting  Nintendo
# 48    49         Super Mario Galaxy      Wii  2007.0  Platform  Nintendo
# 60    61               Just Dance 3      Wii  2011.0      Misc   Ubisoft
#
#     NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      41.49     29.02      3.77         8.46         82.74
# ...

# %% [markdown]
# Q2 => Get the top selling Genre in Japan

# %%
df[['JP_Sales','Genre']].sort_values('JP_Sales', ascending=False).nlargest(10,'JP_Sales').mode()

df_most_Platform=df['Platform'].mode()
df_most_Platform
# Out:
#    JP_Sales         Genre
# 0     10.22  Role-Playing

# %% [markdown]
# Q3 => Get 10 with less sellers in europe from the early years.

# %%
df[['Year','EU_Sales','Name','Genre']].nsmallest(df['Year'].count(),'Year').nsmallest(10,'EU_Sales').sort_values('Year', ascending=True)
# Out:
#          Year  EU_Sales                                 Name     Genre
# 763    1983.0       0.0                              Mahjong      Misc
# 1233   1984.0       0.0                              F1 Race    Racing
# 1324   1984.0       0.0                   4 Nin uchi Mahjong      Misc
# 1857   1984.0       0.0                          Lode Runner    Puzzle
# 2955   1984.0       0.0                                Mappy  Platform
# 1973   1985.0       0.0          Tag Team Match M.U.S.C.L.E.  Fighting
# 2020   1985.0       0.0                            Bomberman    Puzzle
# 3907   1985.0       0.0                        Wrecking Crew  Platform
# 4727   1985.0       0.0                              Dig Dug    Puzzle
# 15867  1985.0       0.0  Strongest Tokyo University Shogi DS    Action
